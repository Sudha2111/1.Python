# %%
from mainfunction import multipleFunctions
# from filename import class name
# Out:
# Enter your Gender : male
# Enter Age: 21
# Eligible
# Subject 1 : 434
# Subject 2 : 45
# Subject 3 : 4
# Subject 4 : 5
# Subject 5 : 6
# Total: 494
# Percentage: 98.8

# %%
multipleFunctions.oddeven()
# Out:
# Enter a number: 4
# 4 is Even number

# %%
multipleFunctions.triangle()
# Out:
# Height: 4
# Breadth: 5
# Area of Triangle: 10.0
# Height1: 4
# Height2: 3
# Breadth: 5
# Perimeter of Triangle: 12

# %%
multipleFunctions.Subfields()
# Out:
# Sub-fields in AI are:
#         Machine Learning
#         Neural Networks
#         Vision
#         Robotics
#         Speech Processing
#         Natural Language Processing

# %%
multipleFunctions.marriage()
# Out:
# Enter your Gender : female
# Enter Age: 43
# Eligible
# 'female'
